# %%
# %load_ext autoreload
# %autoreload 2

# ---
# logging setup
# ---
import logging

from pyClimExtremes.logging.setup_logging import (
    configure_package_logger as configure_pyclimextremes_logger,
 )

configure_pyclimextremes_logger(
    level=logging.DEBUG,
    propagate=True,
    add_handler=True,
    fmt='%(name)s - %(levelname)s - %(message)s'
 )

# ---
# imports
# ---
import subprocess
from pathlib import Path

import netCDF4
import xarray as xr
import numpy as np
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

from pyClimExtremes.indices import get_creatable_quantiles
from pyClimExtremes.scripts.compute_thresholds import compute_thresholds

# ---
# paths
# ---
system = 'victor'  # Change this to 'nird' or 'ipcc' as needed
if system == 'fruh':
    raw_data_path = Path('/home/johannlf/Downloads/raw_input')
    refdir_path = Path('/home/johannlf/Downloads/ETCCDI_output')
    savepath = Path('/home/johannlf/Downloads/homemade_output')
elif system == 'victor':
    raw_data_path = Path('/scratch/johannlf/')
    refdir_path = Path('/scratch/johannlf/ETCCDI_output')
    savepath = Path('/scratch/johannlf/homemade_output')
elif system == 'nird' or system == 'ipcc':
    raw_data_path = Path('/nird/datalake/NS9560K/johannef/test_ETCCDI_calc/raw_input')
    refdir_path = Path('/nird/datalake/NS9560K/johannef/test_ETCCDI_calc/ETCCDI_output')
    savepath = Path('/nird/datalake/NS9560K/johannef/test_ETCCDI_calc/homemade_output')
else:
    raise ValueError(f"Unknown system: {system}")
# Out:
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'fdETCCDI' of type 'temperature' with ID 'fdETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'suETCCDI' of type 'temperature' with ID 'suETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'idETCCDI' of type 'temperature' with ID 'idETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'trETCCDI' of type 'temperature' with ID 'trETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'txxETCCDI' of type 'temperature' with ID 'txxETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'txnETCCDI' of type 'temperature' with ID 'txnETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'tnxETCCDI' of type 'temperature' with ID 'tnxETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'tnnETCCDI' of type 'temperature' with ID 'tnnETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'dtrETCCDI' of type 'temperature' with ID 'dtrETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'cddETCCDI' of type 'precipitation' with ID 'cddETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'cwdETCCDI' of type 'precipitation' with ID 'cwdETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'prcptotETCCDI' of type 'precipitation' with ID 'prcptotETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'rnnmmETCCDI' of type 'precipitation' with ID 'rnnmmETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'r1mmETCCDI' of type 'precipitation' with ID 'r1mmETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'r10mmETCCDI' of type 'precipitation' with ID 'r10mmETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'r20mmETCCDI' of type 'precipitation' with ID 'r20mmETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'rxndayETCCDI' of type 'precipitation' with ID 'rxndayETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'rx1dayETCCDI' of type 'precipitation' with ID 'rx1dayETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'rx5dayETCCDI' of type 'precipitation' with ID 'rx5dayETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'sdiiETCCDI' of type 'precipitation' with ID 'sdiiETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'r95pETCCDI' of type 'precipitation' with ID 'r95pETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'r99pETCCDI' of type 'precipitation' with ID 'r99pETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'r95pTOTETCCDI' of type 'precipitation' with ID 'r95pTOTETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered impact index 'r99pTOTETCCDI' of type 'precipitation' with ID 'r99pTOTETCCDI'.
# pyClimExtremes.indices.registry - DEBUG - Registered quantile 'tn_qXXp' of type 'temperature_quantile' with ID 'tn_qXXp'.
# pyClimExtremes.indices.registry - DEBUG - Registered quantile 'tx_qXXp' of type 'temperature_quantile' with ID 'tx_qXXp'.
# pyClimExtremes.indices.registry - DEBUG - Registered quantile 'pr_qXXp' of type 'precipitation_quantile' with ID 'pr_qXXp'.

# %%
new_files, skipped_files = compute_thresholds(
    quantiles={"tn_qXXp": [10, 50, 90]},
    compute_backend='python',
    output_dir=savepath,
    tasmax=Path(raw_data_path / 'tasmax_day_CanESM5_historical_r1i1p1f1_gn_18500101-20141231.nc'),
    tasmin=Path(raw_data_path / 'tasmin_day_CanESM5_historical_r1i1p1f1_gn_18500101-20141231.nc'),
    pr=None,
    overwrite=True,
    window_size=5,
    bootstrap_samples=False,
    random_seed=None,
    backend_kwargs={"use_cuda_if_available": True}
)
# Out:
# pyClimExtremes.io.data_wrapping - DEBUG - Opened DataWrapper for /scratch/johannlf/tasmax_day_CanESM5_historical_r1i1p1f1_gn_18500101-20141231.nc
# pyClimExtremes.io.save_utils - DEBUG - File tn_q10p_threshold_CanESM5_historical_r1i1p1f1_1981-2010.nc will be overwritten at /scratch/johannlf/homemade_output.
# pyClimExtremes.io.save_utils - DEBUG - Overwriting existing file: /scratch/johannlf/homemade_output/tn_q10p_threshold_CanESM5_historical_r1i1p1f1_1981-2010.nc
# pyClimExtremes.io.save_utils - DEBUG - File tn_q50p_threshold_CanESM5_historical_r1i1p1f1_1981-2010.nc will be overwritten at /scratch/johannlf/homemade_output.
# pyClimExtremes.io.save_utils - DEBUG - Overwriting existing file: /scratch/johannlf/homemade_output/tn_q50p_threshold_CanESM5_historical_r1i1p1f1_1981-2010.nc
# pyClimExtremes.io.save_utils - DEBUG - File tn_q90p_threshold_CanESM5_historical_r1i1p1f1_1981-2010.nc will be overwritten at /scratch/johannlf/homemade_output.
# pyClimExtremes.io.save_utils - DEBUG - Overwriting existing file: /scratch/johannlf/homemade_output/tn_q90p_threshold_CanESM5_historical_r1i1p1f1_1981-2010.nc
# pyClimExtremes.io.data_wrapping - DEBUG - Opened DataWrapper for /scratch/johannlf/tasmin_day_CanESM5_historical_r1i1p1f1_gn_18500101-20141231.nc
# pyClimExtremes.scripts.compute_thresholds - INFO - Computing thresholds for tn_q10p
# pyClimExtremes.indices.base_index - DEBUG - Unfiltered kwargs keys: ['compute_fq', 'group_index', 'quantile', 'base_period_mask', 'window_size', 'bootstrap_samples', 'tasmin_data', 'time_array', 'time_units', 'calendar']
# pyClimExtremes.indices.base_index - DEBUG - Unwrapped method signature parameters: ['self', 'compute_fq', 'tasmin_data', 'group_index', 'quantile', 'base_period_mask', 'time_array', 'time_units', 'calendar', 'window_size', 'bootstrap_samples', 'random_seed']
# pyClimExtremes.indices.base_index - DEBUG - Calling tn_qXXp with kwargs: ['compute_fq', 'group_index', 'quantile', 'base_period_mask', 'window_size', 'bootstrap_samples', 'tasmin_data', 'time_array', 'time_units', 'calendar']
# pyClimExtremes.compute_backend.python_backend_helper_methods - DEBUG - Computing temperature quantiles [10] over 10950 base timesteps, 365 DOYs
# pyClimExtremes.compute_backend.python_backend_helper_methods - DEBUG - Using CUDA GPU acceleration for quantile computation
# pyClimExtremes.scripts.compute_thresholds - INFO - Computing thresholds for tn_q50p
# pyClimExtremes.indices.base_index - DEBUG - Unfiltered kwargs keys: ['compute_fq', 'group_index', 'quantile', 'base_period_mask', 'window_size', 'bootstrap_samples', 'tasmin_data', 'time_array', 'time_units', 'calendar']
# pyClimExtremes.indices.base_index - DEBUG - Unwrapped method signature parameters: ['self', 'compute_fq', 'tasmin_data', 'group_index', 'quantile', 'base_period_mask', 'time_array', 'time_units', 'calendar', 'window_size', 'bootstrap_samples', 'random_seed']
# pyClimExtremes.indices.base_index - DEBUG - Calling tn_qXXp with kwargs: ['compute_fq', 'group_index', 'quantile', 'base_period_mask', 'window_size', 'bootstrap_samples', 'tasmin_data', 'time_array', 'time_units', 'calendar']
# pyClimExtremes.compute_backend.python_backend_helper_methods - DEBUG - Computing temperature quantiles [50] over 10950 base timesteps, 365 DOYs
# pyClimExtremes.compute_backend.python_backend_helper_methods - DEBUG - Using CUDA GPU acceleration for quantile computation
# pyClimExtremes.scripts.compute_thresholds - INFO - Computing thresholds for tn_q90p
# pyClimExtremes.indices.base_index - DEBUG - Unfiltered kwargs keys: ['compute_fq', 'group_index', 'quantile', 'base_period_mask', 'window_size', 'bootstrap_samples', 'tasmin_data', 'time_array', 'time_units', 'calendar']
# pyClimExtremes.indices.base_index - DEBUG - Unwrapped method signature parameters: ['self', 'compute_fq', 'tasmin_data', 'group_index', 'quantile', 'base_period_mask', 'time_array', 'time_units', 'calendar', 'window_size', 'bootstrap_samples', 'random_seed']
# pyClimExtremes.indices.base_index - DEBUG - Calling tn_qXXp with kwargs: ['compute_fq', 'group_index', 'quantile', 'base_period_mask', 'window_size', 'bootstrap_samples', 'tasmin_data', 'time_array', 'time_units', 'calendar']
# pyClimExtremes.compute_backend.python_backend_helper_methods - DEBUG - Computing temperature quantiles [90] over 10950 base timesteps, 365 DOYs
# pyClimExtremes.compute_backend.python_backend_helper_methods - DEBUG - Using CUDA GPU acceleration for quantile computation
# pyClimExtremes.scripts.compute_thresholds - INFO - Threshold computation completed. Total quantiles requested: 3 with timing details:
# Time taken for input checks and loading: 1.43 secs.
# Time taken for threshold computations: 6.36 secs.
#  - Average get_arrays time: 12.89 secs.
#  - Average get_units time: 0.00 secs.
#  - Average compute time: 1.89 secs.
#  - Average write time: 0.23 secs.
# Total time taken: 20.69 secs.
# Detailed timing per quantile:
#  - Quantile 'tn_q10p': 2.65 secs.
#  - Quantile 'tn_q50p': 1.85 secs.
#  - Quantile 'tn_q90p': 1.85 secs.
# New files created: 3.

# %%
new_files, skipped_files = compute_thresholds(
    quantiles={"pr_qXXp": [95, 99]},
    compute_backend='python',
    output_dir=savepath,
    pr=Path(raw_data_path / 'pr_day_CanESM5_historical_r1i1p1f1_gn_18500101-20141231.nc'),
    overwrite=True,
)
# Out:
# pyClimExtremes.io.data_wrapping - DEBUG - Opened DataWrapper for /home/johannlf/Downloads/raw_input/pr_day_CanESM5_historical_r1i1p1f1_gn_18500101-20141231.nc
# pyClimExtremes.io.save_utils - DEBUG - File pr_q95p_threshold_CanESM5_historical_r1i1p1f1_1981-2010.nc will be overwritten at /home/johannlf/Downloads/homemade_output.
# pyClimExtremes.io.save_utils - DEBUG - Overwriting existing file: /home/johannlf/Downloads/homemade_output/pr_q95p_threshold_CanESM5_historical_r1i1p1f1_1981-2010.nc
# pyClimExtremes.io.save_utils - DEBUG - File pr_q99p_threshold_CanESM5_historical_r1i1p1f1_1981-2010.nc will be overwritten at /home/johannlf/Downloads/homemade_output.
# pyClimExtremes.io.save_utils - DEBUG - Overwriting existing file: /home/johannlf/Downloads/homemade_output/pr_q99p_threshold_CanESM5_historical_r1i1p1f1_1981-2010.nc
# pyClimExtremes.io.data_wrapping - DEBUG - Opened DataWrapper for /home/johannlf/Downloads/raw_input/pr_day_CanESM5_historical_r1i1p1f1_gn_18500101-20141231.nc
# pyClimExtremes.scripts.compute_thresholds - INFO - Computing thresholds for pr_q95p
# pyClimExtremes.scripts.compute_thresholds - INFO - Computing thresholds for pr_q99p
# pyClimExtremes.scripts.compute_thresholds - INFO - Threshold computation completed. Total quantiles requested: 2 with timing details:
# Time taken for input checks and loading: 0.84 secs.
# Time taken for threshold computations: 5.41 secs.
#  - Average get_arrays time: 14.48 secs.
#  - Average get_units time: 0.00 secs.
#  - Average compute time: 2.70 secs.
#  - Average write time: 0.00 secs.
# Total time taken: 20.73 secs.
# Detailed timing per quantile:
#  - Quantile 'pr_q95p': 2.71 secs.
#  - Quantile 'pr_q99p': 2.70 secs.
# New files created: 2.

# %%
creatable_quantile_ids = list(get_creatable_quantiles(subset="all", print_msg=True).keys())
# Out:
# Available creatable quantiles:
#  - tn_qXXp: Custom percentile of daily minimum temperature during the baseline period *,
#  - tx_qXXp: Custom percentile of daily maximum temperature during the baseline period *,
#  - pr_qXXp: Custom percentile of daily precipitation during the baseline period *,
#
# * custom quantile values must be provided through compute_thresholds(quantiles={index_id: [q1, q2, ...]}).

# %%
from numba import cuda
print("CUDA available:", cuda.gpus)
# Out:
# CUDA available: <Managed Device 0>, <Managed Device 1>

# %%
index_ids = list(get_creatable_indices(subset="precipitation", print_msg=True).keys())
# Out:
# Available creatable precipitation indices:
#  - cddETCCDI: Consecutive dry days,
#  - cwdETCCDI: Consecutive wet days,
#  - prcptotETCCDI: Annual total precipitation in wet days,
#  - rnnmmETCCDI: Number of heavy precipitation days *,
#  - r1mmETCCDI: Annual total wet-day precipitation,
#  - r10mmETCCDI: Annual total heavy precipitation,
#  - r20mmETCCDI: Annual total very heavy precipitation,
#  - rxndayETCCDI: Maximum n-day precipitation *,
#  - rx1dayETCCDI: Monthly maximum 1-day precipitation,
#  - rx5dayETCCDI: Monthly maximum 5-day precipitation,
#  - sdiiETCCDI: Simple daily intensity index,
#  - r95pETCCDI: Annual total precipitation when daily precipitation exceeds the 95th percentile of wet-day precipitation,
#  - r99pETCCDI: Annual total precipitation when daily precipitation exceeds the 99th percentile of wet-day precipitation,
#  - r95pTOTETCCDI: Contribution of very wet days to total precipitation (%),
#  - r99pTOTETCCDI: Contribution of extremely wet days to total precipitation (%),
#  - pr_q95p: Annual total precipitation on very wet days (>95th percentile),
#  - pr_q99p: Annual total precipitation on extremely wet days (>99th percentile),
#
# * custom threshold X must be provided. Provide through kwargs = {'threshold': {index_ID: X}}.

# %%
# Out:
# pyClimExtremes.indices.registry - DEBUG - Resolved indices to compute: [<class 'pyClimExtremes.indices.quantile_indices.pr_q95pIndex'>, <class 'pyClimExtremes.indices.quantile_indices.pr_q99pIndex'>]
# pyClimExtremes.io.data_wrapping - DEBUG - Opened DataWrapper for /home/johannlf/Downloads/raw_input/pr_day_CanESM5_historical_r1i1p1f1_gn_18500101-20141231.nc
# pyClimExtremes.scripts.compute_thresholds - ERROR - Input variable 'pr' cannot be a masked array for quantile threshold computation.
# Stack (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/johannlf/miniforge3/envs/pyClimExtremes/lib/python3.14/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/johannlf/miniforge3/envs/pyClimExtremes/lib/python3.14/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/johannlf/miniforge3/envs/pyClimExtremes/lib/python3.14/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/home/johannlf/miniforge3/envs/pyClimExtremes/lib/python3.14/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/home/johannlf/miniforge3/envs/pyClimExtremes/lib/python3.14/asyncio/base_events.py", line 677, in run_forever
#     self._run_once()
#   File "/home/johannlf/miniforge3/envs/pyClimExtremes/lib/python3.14/asyncio/base_events.py", line 2057, in _run_once
#     handle._run()
#   File "/home/johannlf/miniforge3/envs/pyClimExtremes/lib/python3.14/asyncio/events.py", line 94, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/johannlf/miniforge3/envs/pyClimExtremes/lib/python3.14/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/home/johannlf/miniforge3/envs/pyClimExtremes/lib/python3.14/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/home/johannlf/miniforge3/envs/pyClimExtremes/lib/python3.14/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/johannlf/miniforge3/envs/pyClimExtremes/lib/python3.14/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/home/johannlf/miniforge3/envs/pyClimExtremes/lib/python3.14/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "/home/johannlf/miniforge3/envs/pyClimExtremes/lib/python3.14/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/johannlf/miniforge3/envs/pyClimExtremes/lib/python3.14/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell
#     result = self._run_cell(
#   File "/home/johannlf/miniforge3/envs/pyClimExtremes/lib/python3.14/site-packages/IPython/core/interactiveshell.py", line 3224, in _run_cell
#     result = runner(coro)
#   File "/home/johannlf/miniforge3/envs/pyClimExtremes/lib/python3.14/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/johannlf/miniforge3/envs/pyClimExtremes/lib/python3.14/site-packages/IPython/core/interactiveshell.py", line 3446, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/johannlf/miniforge3/envs/pyClimExtremes/lib/python3.14/site-packages/IPython/core/interactiveshell.py", line 3687, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/johannlf/miniforge3/envs/pyClimExtremes/lib/python3.14/site-packages/IPython/core/interactiveshell.py", line 3747, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_231423/1405748442.py", line 1, in <module>
#     new_files, skipped_files = compute_thresholds(
#   File "/home/johannlf/Documents/pyClimExtremes/src/pyClimExtremes/scripts/compute_thresholds.py", line 83, in compute_thresholds
#     lon_var = ds.createVariable("lon", "f4", ("lon",))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 new_files, skipped_files = compute_thresholds(
#       2     quantiles="precipitation",
#       3     compute_backend='python',
#       4     output_dir=savepath,
#
# File ~/Documents/pyClimExtremes/src/pyClimExtremes/scripts/compute_thresholds.py:84, in compute_thresholds(quantiles, compute_backend, output_dir, tasmax, tasmin, pr, overwrite, window_size, bootstrap_samples, random_seed, **kwargs)
#      81 lat_var.units = "degrees_north"
#      83 lon_var = ds.createVariable("lon", "f4", ("lon",))
# ---> 84 lon_var[:] = lon
#      85 lon_var.standard_name = "longitude"
#      86 lon_var.units = "degrees_east"
#
# ValueError: Input variable 'pr' cannot be a masked array for quantile threshold computation.

# %%
new_files
# Out:
# [PosixPath('/home/johannlf/Downloads/homemade_output/pr_q95p_threshold_CanESM5_historical_r1i1p1f1_1981-2010.nc'),
#  PosixPath('/home/johannlf/Downloads/homemade_output/pr_q99p_threshold_CanESM5_historical_r1i1p1f1_1981-2010.nc')]

# %%
compute_fqs = ['mon', 'yr']
for index_id in index_ids:
    index_files_homemade =  [file for file in new_files if all(substring in file.name for substring in [index_id, 'historical'])]
    index_files_ref = list(refdir_path.glob(f'{index_id}_*historical*.nc'))
    if len(index_files_homemade) != 1 or len(index_files_ref) != 1:
        print(f"Skipping {index_id} at due to unexpected number of files. Homemade: {len(index_files_homemade)}, ref: {len(index_files_ref)}")
        print("")
        continue

    print(f'Checking for {index_id}')
    homemade_file = index_files_homemade[0]
    ref_file = index_files_ref[0]
    ref_ds = xr.open_dataset(ref_file, decode_timedelta=False)
    homemade_ds = xr.open_dataset(homemade_file, decode_timedelta=False)

    # --- check that the dimensions are equal
    print(" * Checking dimensions...")
    for dim in ref_ds.sizes:
        ref_dim = ref_ds.sizes[dim]
        homemade_dim = homemade_ds.sizes[dim]
        print(f"    * Reference dimension {dim}: {ref_dim}")
        print(f"    * Homemade dimension {dim}: {homemade_dim}")
        assert ref_ds.sizes[dim] == homemade_ds.sizes[dim], f"Dimension {dim} does not match: {ref_ds.sizes[dim]} != {homemade_ds.sizes[dim]}"

    # --- check that coordinates are equal
    print(" * Checking coordinates...")
    for coord in [coord for coord in ref_ds.coords if coord not in ['height']]:
        ref_coord = ref_ds[coord]
        homemade_coord = homemade_ds[coord]

        diff = ref_coord.values - homemade_coord.values
        if diff.dtype == 'float64':
            diff = np.abs(diff)
            assert (diff < 1e-5).all(), f"Coordinate {coord} does not match"
        else:
            import datetime
            assert all(val == datetime.timedelta(0) for val in diff), f"Coordinate {coord} does not match"
        print(f"    * Coordinate {coord} matches.")

    # --- plot
    fig, axs = plt.subplots(
        2, 3,
        figsize=(15, 12),
        subplot_kw={'projection': ccrs.PlateCarree()}
    )
    # Replace bottom row with regular (non-projection) axes for line plots
    for j in range(3):
        axs[1, j] = fig.add_subplot(2, 3, 4 + j)
    homemade_ds[index_id].isel(time=0).plot(ax=axs[0,1])
    ref_ds[index_id].isel(time=0).plot(ax=axs[0,0])
    diff = ref_ds[index_id].values - homemade_ds[index_id].values
    diff_da = xr.DataArray(diff, coords=ref_ds[index_id].coords, dims=ref_ds[index_id].dims)
    diff_da.isel(time=0).plot(ax=axs[0,2])

    nanmean_diff = np.nanmean(diff, axis=(1, 2))
    axs[1, 2].plot(nanmean_diff)
    # find the difference in order of magnitude between diff and ref_ds[index_id]
    order_of_magnitude_ref = np.floor(np.log10(np.nanmax(np.abs(ref_ds[index_id].values))))
    order_of_magnitude_nanmeandiff = np.floor(np.log10(np.nanmax(np.abs(nanmean_diff))))
    magnitude_diff = order_of_magnitude_ref - order_of_magnitude_nanmeandiff
    axs[1, 2].set_title(f'Mean difference over space\n O(ref)={order_of_magnitude_ref:.0f}, O(mean(diff, axis=(1, 2)))={order_of_magnitude_nanmeandiff:.0f}')

    nanmax_diff = np.nanmax(diff, axis=(1, 2))
    axs[1, 1].plot(nanmax_diff)
    # find the difference in order of magnitude between diff and ref_ds[index_id]
    order_of_magnitude_ref = np.floor(np.log10(np.nanmax(np.abs(ref_ds[index_id].values))))
    order_of_magnitude_nanmaxdiff = np.floor(np.log10(np.nanmax(np.abs(nanmax_diff))))
    magnitude_diff = order_of_magnitude_ref - order_of_magnitude_nanmaxdiff
    axs[1, 1].set_title(f'Max difference over space\n O(ref)={order_of_magnitude_ref:.0f}, O(max(diff, axis=(1, 2)))={order_of_magnitude_nanmaxdiff:.0f}')

    fig.suptitle(f'Index: {index_id}, Unit: {ref_ds[index_id].units}/{homemade_ds[index_id].units}')
    axs[0, 0].set_title('Reference')
    axs[0, 1].set_title('Homemade')
    axs[0, 2].set_title('Difference (Ref - Homemade)')
    plt.show()
    print("")
# Out:
# Skipping pr_q95p at due to unexpected number of files. Homemade: 1, ref: 0
#
# Skipping pr_q99p at due to unexpected number of files. Homemade: 1, ref: 0
